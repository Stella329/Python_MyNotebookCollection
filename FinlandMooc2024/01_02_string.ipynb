# %% [markdown]
# ## 题目：倒叙输出string
# End to Begining
#
# <Finland Mooc 2024>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
string = input('Please type in a string: ')
for item in range(1,len(string)+1):
    index = item * -1
    print(string[index])

# %%
# Solution for part03-10_end_to_beginning
input_string = input("Please type in a string: ")
index = -1
while index >= -len(input_string):
    print(input_string[index])
    index -= 1

# %% [markdown]
# ## 题目：A framed word
#
# <Finland Mooc> Intro Part3 -> Topic 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here
word = input('Word:')
_1stline = '*'*30
space_len = 30-2-len(word)

space1 = space_len//2
if len(word)%2 !=0:
    space2 = space1+1
else:
    space2 = space1

print(_1stline)
print('*'+ space1*' ' + word + space2*' ' + '*' )
print(_1stline)

# %% [markdown]
# ## 题目：Slice String -Reversed

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here

word = input('Please type in a string: ')
step = 1

while step <=len(word):
    print(word[-1*step:])
    step+=1

# %%
# Solution for part03-18_substrings_part_2 --src/substrings_part_2.py

string = input("Please type in a string: ")
 
start = len(string) - 1
while start >= 0:
    print(string[start:])
    start -= 1

# %% [markdown]
# ## 题目：string.find() --Find all the substrings
# part 3 -> section2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here

word = input("Please type in a word: ")
character = input ("Please type in a character: ")
step = len(word)

while step>0:
    index = word.find(character)
    if index != -1 and len(word)-index >= 3:
        print(word[index:(index+3)])
        word = word[index+1:]
        # print(word)

        step = len(word)
        # print(step)
    else:
        break

# %%
# Solution for part03-21_find_all_substrings

word = input("Please type in a word: ")
character = input("Please type in a character: ")
 
index = 0
 
while index + 3 <= len(word):
    if word[index] == character:
        print(word[index:index+3])
    index += 1

# %%
# hint
word = input("Word: ")
while word:
    print(word)
    if len(word) < 2:
        break
    word = word[2:]

# %% [markdown]
# ## 题目：string.find() --The second occurrence

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your solution here

string = input('Please type in a string:')
substring = input('Please type in a substring:')

index1 = string.find(substring)

if index1 != -1:
    string2 = string[index1+len(substring):] 
    index2 = string2.find(substring)
    # print(f"string={string}")
    # print(f"string2={string2}")
    move = len(string) - len(string2)

    if index2 == -1:
        print('The substring does not occur twice in the string.')
    else:
        print(f"The second occurrence of the substring is at index {index2+move}.")
else:
    print('The substring does not occur twice in the string.')

# %%
# Solution for part03-22_second_occurrence

string = input("Please type in a string: ")
substring = input("Please type in a substring: ")
 
index1 = string.find(substring)
index2 = -1
if index1 != -1:
    string = string[index1+len(substring):]
    index2 = string.find(substring)
 
if index2 == -1:
    print("The substring does not occur twice in the string.")
else:
    print("The second occurrence of the substring is at index " + str(index1+len(substring)+index2) +  ".")
